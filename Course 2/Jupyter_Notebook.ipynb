# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Sylvain</b><br>
# Data Scientist

# %% [markdown]
# <i>I am interested in data science because I like mathematics, programming, and solving problems, which seems to be some of the key components of data science.</i>

# %% [markdown]
# <h3>The code in the next cell is written in Python and will display the sentence "Thanks for grading my notebook, I hope you like the course too!"

# %%
print("Thanks for grading my notebook, I hope you like the course too!")
# Out:
# Thanks for grading my notebook, I hope you like the course too!

# %% [markdown]
# <h5>horizontal rule:</h5>
# <hr>
# <h5>Bullet points & Hyperlink:</h5>
# <ul>
# <li><a href="http://en.wikipedia.org/wiki/Bullet_points">Bullet points</a></li>
# <li><a href="http://en.wikipedia.org/wiki/Bullet_points">Bullet points</a></li>
# <li><a href="http://en.wikipedia.org/wiki/Bullet_points">Bullet points</a></li>
# </ul>
# <h5>Numbered List</h5>
# <ol>
# <li>First Item</li>
# <li>Second Item</li>
# <li>Third Item</li>
# </ol>
